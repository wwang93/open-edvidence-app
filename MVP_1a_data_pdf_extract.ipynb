# %% [markdown]
# <a href="https://colab.research.google.com/github/wwang93/open-edvidence-app/blob/main/MVP_1a_data_pdf_extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install pymupdf langchain-text-splitters
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 83.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import json
from pathlib import Path
from typing import Dict, List, Tuple, Any

import fitz  # PyMuPDF
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
# ----------------------------
# 2) Configure paths
# ----------------------------
# TODO: set these paths to your Drive folder
INPUT_DIR = Path("/content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports")
OUTPUT_DIR = INPUT_DIR  # save outputs in same folder

OUTPUT_JSON = OUTPUT_DIR / "intervention_reports_chunks.json"
ERRORS_JSON = OUTPUT_DIR / "intervention_reports_errors.json"

# Chunk config
CHUNK_SIZE = 1500
CHUNK_OVERLAP = 200

# %%
# ----------------------------
# 3) Helpers
# ----------------------------
def normalize_report_id(filename: str) -> str:
    """
    Turn original PDF filename into a stable ID:
    - remove extension
    - lowercase
    - replace non-alphanumeric with underscores
    - collapse multiple underscores
    """
    stem = Path(filename).stem
    stem = stem.strip().lower()
    stem = re.sub(r"[^a-z0-9]+", "_", stem)
    stem = re.sub(r"_+", "_", stem).strip("_")
    return stem


def extract_pdf_text(pdf_path: Path) -> str:
    """Extract plain text from all pages. Returns a single string."""
    parts: List[str] = []
    with fitz.open(str(pdf_path)) as doc:
        for page in doc:
            txt = page.get_text("text") or ""
            parts.append(txt)
    return "\n".join(parts).strip()


def build_splitter(chunk_size: int, chunk_overlap: int):
    return RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,            # characters
        chunk_overlap=chunk_overlap,
        separators=["\n\n", "\n", ". ", " ", ""],
    )


def chunk_text(text: str, splitter: RecursiveCharacterTextSplitter) -> List[str]:
    text = text.strip()
    if not text:
        return []
    chunks = splitter.split_text(text)
    # clean up chunk whitespace
    chunks = [c.strip() for c in chunks if c and c.strip()]
    return chunks

# %%
# ----------------------------
# 4) Batch processing
# ----------------------------
pdf_files = sorted(INPUT_DIR.glob("*.pdf"))
print(f"Found {len(pdf_files)} PDFs in: {INPUT_DIR}")

splitter = build_splitter(CHUNK_SIZE, CHUNK_OVERLAP)

output: Dict[str, str] = {}
errors: Dict[str, Any] = {}

for pdf_path in pdf_files:
    report_id = normalize_report_id(pdf_path.name)
    try:
        text = extract_pdf_text(pdf_path)

        if not text:
            errors[pdf_path.name] = {"error": "empty_text_after_extraction"}
            continue

        chunks = chunk_text(text, splitter)

        if not chunks:
            errors[pdf_path.name] = {"error": "no_chunks_created"}
            continue

        # write chunks into output dict with normalized names:
        # report_id__chunk0001, report_id__chunk0002 ...
        for i, c in enumerate(chunks, start=1):
            key = f"{report_id}__chunk{i:04d}"
            if key in output:
                # extremely unlikely, but safe guard
                errors[pdf_path.name] = {"error": "duplicate_chunk_key", "key": key}
                continue
            output[key] = c

        print(f"OK  - {pdf_path.name}: {len(chunks)} chunks")

    except Exception as e:
        errors[pdf_path.name] = {"error": "exception", "message": str(e)}
        print(f"ERR - {pdf_path.name}: {e}")
# Out:
# Found 277 PDFs in: /content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports
# OK  - PLATO_030210.pdf: 27 chunks
# OK  - WWC-InterventionReport_Effect-of-FLIGHT_Snapshot_040119.pdf: 3 chunks
# OK  - WWC-PEPPER_IR-Snapshot_InsideTrack_508.pdf: 3 chunks
# OK  - WWC-red-light-purple-light_report.pdf: 25 chunks
# OK  - WWC_AccelMiddleSch_070808.pdf: 13 chunks
# OK  - WWC_Arthur_091406.pdf: 17 chunks
# OK  - WWC_BCIRC_021507.pdf: 33 chunks
# OK  - WWC_Building-Blocks_report.pdf: 26 chunks
# OK  - WWC_Building_Blocks_072307.pdf: 32 chunks
# OK  - WWC_Building_Decision_090806.pdf: 23 chunks
# OK  - WWC_CWFIT_IR-report.pdf: 38 chunks
# OK  - WWC_CWPT_070907.pdf: 22 chunks
# OK  - WWC_Caring_School_042307.pdf: 23 chunks
# OK  - WWC_Connect_Kids_091406.pdf: 20 chunks
# OK  - WWC_Corrective_Reading_070207.pdf: 41 chunks
# OK  - WWC_DCMP_IR-snapshot.pdf: 3 chunks
# OK  - WWC_DLP_IR-Report.pdf: 48 chunks
# OK  - WWC_Daisy_Quest_read_092806.pdf: 15 chunks
# OK  - WWC_Dialogic_Reading_020807.pdf: 93 chunks
# OK  - WWC_Direct_Instruction_052107.pdf: 70 chunks
# OK  - WWC_Drugs_091406.pdf: 38 chunks
# OK  - WWC_Drugs_Violence_091406.pdf: 25 chunks
# OK  - WWC_Ethics_Curriculum_090806.pdf: 11 chunks
# OK  - WWC_Expert_Mathematician_101206.pdf: 14 chunks
# OK  - WWC_FTF_012408.pdf: 13 chunks
# OK  - WWC_Facing_History_090806.pdf: 35 chunks
# OK  - WWC_Failure_Free_070207.pdf: 53 chunks
# OK  - WWC_Fast_ForWord_092806.pdf: 10 chunks
# OK  - WWC_Financial_Incentives_122106.pdf: 53 chunks
# OK  - WWC_Fluency_Formula_061107.pdf: 31 chunks
# OK  - WWC_GBG_IR-report.pdf: 67 chunks
# OK  - WWC_GrowthMindset_IR_snapshot.pdf: 4 chunks
# OK  - WWC_HS_Redirection_041607.pdf: 56 chunks
# OK  - WWC_Houghton_Mifflin_043007.pdf: 31 chunks
# OK  - WWC_I-BEST_Snapshot_508.pdf: 3 chunks
# OK  - WWC_ICLL_102606.pdf: 42 chunks
# OK  - WWC_IR_Bottom-Line_SNAPSHOT_508.pdf: 4 chunks
# OK  - WWC_IR_Pathway_Project-snapshot.pdf: 3 chunks
# OK  - WWC_IR_Single_Stop_Snapshot_Nov2020.pdf: 3 chunks
# OK  - WWC_Intervention_Snapshot_OLI_508.pdf: 3 chunks
# OK  - WWC_Jobcorps_040108.pdf: 37 chunks
# OK  - WWC_Jobstart_031808.pdf: 28 chunks
# OK  - WWC_Kaplan_Spellread_070907.pdf: 12 chunks
# OK  - WWC_LASER_IR-snapshot.pdf: 4 chunks
# OK  - WWC_Ladders_Literacy_072307.pdf: 79 chunks
# OK  - WWC_Lessons_in_Character_090806.pdf: 46 chunks
# OK  - WWC_Little_Books_042307.pdf: 20 chunks
# OK  - WWC_NewChance_012408.pdf: 10 chunks
# OK  - WWC_PS_FOSS_IR_apr2021.pdf: 8 chunks
# OK  - WWC_Peer_Tutoring_070907.pdf: 32 chunks
# OK  - WWC_Phonological_Awareness_121406.pdf: 84 chunks
# OK  - WWC_Proactive_Reading092806.pdf: 41 chunks
# OK  - WWC_Progress_Math_042307.pdf: 23 chunks
# OK  - WWC_ProjectQUEST_IR-snapshot.pdf: 4 chunks
# OK  - WWC_Project_ALAS_100506.pdf: 38 chunks
# OK  - WWC_Project_GRAD_073007.pdf: 41 chunks
# OK  - WWC_QOP_070207.pdf: 43 chunks
# OK  - WWC_RA_IR-report.pdf: 33 chunks
# OK  - WWC_RR_IR-report.pdf: 51 chunks
# OK  - WWC_RWT_050707.pdf: 34 chunks
# OK  - WWC_Reading_Mastery_092806.pdf: 23 chunks
# OK  - WWC_SBC_Snapshot_508.pdf: 4 chunks
# OK  - WWC_SMART_061107.pdf: 36 chunks
# OK  - WWC_Skills_Action_092806.pdf: 10 chunks
# OK  - WWC_Skills_Adolescent_092806.pdf: 14 chunks
# OK  - WWC_SocialBelonging_IR_snapshot.pdf: 3 chunks
# OK  - WWC_Sound_Foundations_043007.pdf: 74 chunks
# OK  - WWC_Stepping_Stones_062507.pdf: 27 chunks
# OK  - WWC_Talent_Development_071607.pdf: 31 chunks
# OK  - WWC_Talent_Search_122806.pdf: 25 chunks
# OK  - WWC_Transition_Math_031207.pdf: 37 chunks
# OK  - WWC_Twelve_Together_031207.pdf: 10 chunks
# OK  - WWC_VIP_101906.pdf: 27 chunks
# OK  - WWC_Violence_091406.pdf: 10 chunks
# OK  - WWC_Voices_091406.pdf: 27 chunks
# OK  - WWC_Voyager_072307.pdf: 41 chunks
# OK  - WWC_Waterford_071607.pdf: 39 chunks
# OK  - WWC_Wilson_Reading_070207.pdf: 43 chunks
# OK  - WWC_Words_concepts_031207.pdf: 36 chunks
# OK  - WWC_YearUp_IR-snapshot.pdf: 3 chunks
# OK  - WWC_pre-k-mathematics_report.pdf: 28 chunks
# OK  - WWC_world-of-words_report.pdf: 26 chunks
# OK  - wwc_AL_XR_snapshot_mar2021.pdf: 3 chunks
# OK  - wwc_ALitss_snapshot_apr2020.pdf: 3 chunks
# OK  - wwc_ALprj_snapshot_nov2019.pdf: 4 chunks
# OK  - wwc_EESL_bl_snapshot_mar2020.pdf: 3 chunks
# OK  - wwc_EESL_eMIN_snapshot_apr2020.pdf: 3 chunks
# OK  - wwc_EESL_ldc_snapshot_mar2021.pdf: 3 chunks
# OK  - wwc_EESL_nisl_IR_mar2021.pdf: 8 chunks
# OK  - wwc_EL_WG_snapshot_apr2020.pdf: 4 chunks
# OK  - wwc_PM_UCSMP_snapshot_may2021.pdf: 3 chunks
# OK  - wwc_PM_mathex_snapshot_may2021.pdf: 3 chunks
# OK  - wwc_PS_STeLLA_snapshot_may2021.pdf: 3 chunks
# OK  - wwc_SLE_PATHS_snapshot_mar2021.pdf: 3 chunks
# OK  - wwc_STEM_FFO_IR_mar2020.pdf: 33 chunks
# OK  - wwc_STEM_PBIS_IR_mar2020.pdf: 8 chunks
# OK  - wwc_academy_reading_121614.pdf: 19 chunks
# OK  - wwc_accel_reader_081010.pdf: 107 chunks
# OK  - wwc_acceleratedreader_061416.pdf: 59 chunks
# OK  - wwc_acceleratedreader_120809.pdf: 6 chunks
# OK  - wwc_act_sat_100416.pdf: 65 chunks
# OK  - wwc_alachieve_022718.pdf: 66 chunks
# OK  - wwc_alpha_phonics_070110.pdf: 7 chunks
# OK  - wwc_aries_050812.pdf: 33 chunks
# OK  - wwc_aspire_053117.pdf: 20 chunks
# OK  - wwc_avid_091410.pdf: 34 chunks
# OK  - wwc_barton_070110.pdf: 8 chunks
# OK  - wwc_bookclubs_091410.pdf: 81 chunks
# OK  - wwc_brachieve_022718.pdf: 46 chunks
# OK  - wwc_bridges_041409.pdf: 7 chunks
# OK  - wwc_brightbeginnings_030513.pdf: 45 chunks
# OK  - wwc_btl_082608.pdf: 11 chunks
# OK  - wwc_carbo_101514.pdf: 18 chunks
# OK  - wwc_careeracademies_092215.pdf: 46 chunks
# OK  - wwc_ccvyp_052709.pdf: 4 chunks
# OK  - wwc_checkconnect_050515.pdf: 50 chunks
# OK  - wwc_checkconnect_102511.pdf: 16 chunks
# OK  - wwc_chemistry_021412.pdf: 33 chunks
# OK  - wwc_circ_062612.pdf: 53 chunks
# OK  - wwc_circ_083110.pdf: 34 chunks
# OK  - wwc_cmp_021417.pdf: 77 chunks
# OK  - wwc_cognitivetutor_122116.pdf: 113 chunks
# OK  - wwc_copingpower_102511.pdf: 68 chunks
# OK  - wwc_coreplus_092110.pdf: 16 chunks
# OK  - wwc_cori_081010.pdf: 22 chunks
# OK  - wwc_corrective_reading_091410.pdf: 55 chunks
# OK  - wwc_creativecurriculum_030513.pdf: 76 chunks
# OK  - wwc_credit_050515.pdf: 11 chunks
# OK  - wwc_curiosity_010609.pdf: 70 chunks
# OK  - wwc_cwpt_091410.pdf: 6 chunks
# OK  - wwc_daisyquest_preschool_092206.pdf: 26 chunks
# OK  - wwc_destmath_102108.pdf: 5 chunks
# OK  - wwc_dialogic_reading_042710.pdf: 47 chunks
# OK  - wwc_doors_062513.pdf: 59 chunks
# OK  - wwc_dreambox_121013.pdf: 28 chunks
# OK  - wwc_dual_enrollment_022817.pdf: 137 chunks
# OK  - wwc_dyslexia_070110.pdf: 5 chunks
# OK  - wwc_earlyrisers_060512.pdf: 70 chunks
# OK  - wwc_earobics_011309.pdf: 56 chunks
# OK  - wwc_eir_112508.pdf: 28 chunks
# OK  - wwc_envisionmath_010317.pdf: 17 chunks
# OK  - wwc_everydaymath_111015.pdf: 54 chunks
# OK  - wwc_fastfw_083110.pdf: 111 chunks
# OK  - wwc_fasttrack_100714.pdf: 129 chunks
# OK  - wwc_fba_011017.pdf: 235 chunks
# OK  - wwc_ffw_031913.pdf: 208 chunks
# OK  - wwc_firststep_030612.pdf: 63 chunks
# OK  - wwc_firstyear_020916.pdf: 57 chunks
# OK  - wwc_firstyear_102116.pdf: 135 chunks
# OK  - wwc_fundations_070110.pdf: 4 chunks
# OK  - wwc_gems_060512.pdf: 29 chunks
# OK  - wwc_gemsseasons_012913.pdf: 32 chunks
# OK  - wwc_greatbooks_070611.pdf: 15 chunks
# OK  - wwc_greendot_012318.pdf: 71 chunks
# OK  - wwc_hcz_012318.pdf: 18 chunks
# OK  - wwc_headsprout_102709.pdf: 29 chunks
# OK  - wwc_headstart_042517.pdf: 146 chunks
# OK  - wwc_herman_070110.pdf: 4 chunks
# OK  - wwc_houghton_021015.pdf: 11 chunks
# OK  - wwc_ihaveadream_031009.pdf: 7 chunks
# OK  - wwc_incredibleyears_020712.pdf: 65 chunks
# OK  - wwc_incredibleyears_111511.pdf: 62 chunks
# OK  - wwc_investigations_021213.pdf: 57 chunks
# OK  - wwc_invitationlit_121608.pdf: 5 chunks
# OK  - wwc_kipp_012318.pdf: 105 chunks
# OK  - wwc_kumon_031009.pdf: 4 chunks
# OK  - wwc_ladders_031213.pdf: 55 chunks
# OK  - wwc_language_021213.pdf: 38 chunks
# OK  - wwc_letter_062513.pdf: 71 chunks
# OK  - wwc_letus_050812.pdf: 8 chunks
# OK  - wwc_leveledliteracy_091917.pdf: 77 chunks
# OK  - wwc_lexia_063009.pdf: 73 chunks
# OK  - wwc_lindamood_031610.pdf: 87 chunks
# OK  - wwc_lindamood_111015.pdf: 71 chunks
# OK  - wwc_linked_111814.pdf: 105 chunks
# OK  - wwc_lit_express_072710.pdf: 131 chunks
# OK  - wwc_lovaas_082410.pdf: 36 chunks
# OK  - wwc_mathinc_082608.pdf: 14 chunks
# OK  - wwc_maththematics_102108.pdf: 5 chunks
# OK  - wwc_mchs_031709.pdf: 45 chunks
# OK  - wwc_milieu_042412.pdf: 89 chunks
# OK  - wwc_mtp_061615.pdf: 37 chunks
# OK  - wwc_mtpprek_021318.pdf: 22 chunks
# OK  - wwc_nbpts_021318.pdf: 138 chunks
# OK  - wwc_newcent_082608.pdf: 6 chunks
# OK  - wwc_ngyc_092910.pdf: 16 chunks
# OK  - wwc_ntc_070716.pdf: 49 chunks
# OK  - wwc_odyssey_reading_013112.pdf: 17 chunks
# OK  - wwc_odysseymath_013117.pdf: 51 chunks
# OK  - wwc_opencourt_081412.pdf: 46 chunks
# OK  - wwc_opencourt_102114.pdf: 93 chunks
# OK  - wwc_ortongill_070110.pdf: 14 chunks
# OK  - wwc_pals_012913.pdf: 29 chunks
# OK  - wwc_pals_013112.pdf: 64 chunks
# OK  - wwc_pals_050112.pdf: 63 chunks
# OK  - wwc_pals_060512.pdf: 66 chunks
# OK  - wwc_pals_092910.pdf: 17 chunks
# OK  - wwc_pat_060512.pdf: 139 chunks
# OK  - wwc_pat_lk_100716.pdf: 82 chunks
# OK  - wwc_pearson_112117.pdf: 67 chunks
# OK  - wwc_ph_lit_112117.pdf: 16 chunks
# OK  - wwc_playbased_042412.pdf: 29 chunks
# OK  - wwc_pm_icanlearn_082917.pdf: 60 chunks
# OK  - wwc_pmacceleratedmath_121917.pdf: 109 chunks
# OK  - wwc_positive_action_042307.pdf: 39 chunks
# OK  - wwc_prekmath_121713.pdf: 53 chunks
# OK  - wwc_project_SEED_032012.pdf: 12 chunks
# OK  - wwc_project_read_070110.pdf: 50 chunks
# OK  - wwc_projectcriss_061510.pdf: 40 chunks
# OK  - wwc_prt_011017.pdf: 131 chunks
# OK  - wwc_puente_041712.pdf: 16 chunks
# OK  - wwc_puente_072809.pdf: 7 chunks
# OK  - wwc_read180_071310.pdf: 18 chunks
# OK  - wwc_read180_112916.pdf: 180 chunks
# OK  - wwc_read_naturally_072710.pdf: 43 chunks
# OK  - wwc_reading_apprenticeship_071310.pdf: 33 chunks
# OK  - wwc_readingedge_062612.pdf: 38 chunks
# OK  - wwc_readingmastery_071712.pdf: 41 chunks
# OK  - wwc_readingmastery_112613.pdf: 56 chunks
# OK  - wwc_readingplus_091410.pdf: 15 chunks
# OK  - wwc_readingrecovery_122409.pdf: 7 chunks
# OK  - wwc_readmast_081010.pdf: 100 chunks
# OK  - wwc_readnaturally_031913.pdf: 45 chunks
# OK  - wwc_readnaturally_070710.pdf: 48 chunks
# OK  - wwc_readnaturally_070913.pdf: 97 chunks
# OK  - wwc_readrecovery_071613.pdf: 126 chunks
# OK  - wwc_readwell_060810.pdf: 32 chunks
# OK  - wwc_readysetleap_100708.pdf: 64 chunks
# OK  - wwc_rec_teach_091410.pdf: 74 chunks
# OK  - wwc_reciprocalteaching_112613.pdf: 27 chunks
# OK  - wwc_reconnect_050515.pdf: 10 chunks
# OK  - wwc_repeatedreading_051314.pdf: 120 chunks
# OK  - wwc_residential_111814.pdf: 9 chunks
# OK  - wwc_saxon_052416.pdf: 56 chunks
# OK  - wwc_saxonmath_051617.pdf: 100 chunks
# OK  - wwc_secondstep_030513.pdf: 18 chunks
# OK  - wwc_sfa_032817.pdf: 239 chunks
# OK  - wwc_sfa_100212.pdf: 20 chunks
# OK  - wwc_sfaw_052913.pdf: 49 chunks
# OK  - wwc_sharedbook_041415.pdf: 131 chunks
# OK  - wwc_singaporemath_122215.pdf: 15 chunks
# OK  - wwc_siop_022013.pdf: 20 chunks
# OK  - wwc_slp_101818.pdf: 94 chunks
# OK  - wwc_sm_icanlearn_082917.pdf: 58 chunks
# OK  - wwc_smacceleratedmath_121917.pdf: 45 chunks
# OK  - wwc_socialskills_020513.pdf: 74 chunks
# OK  - wwc_soundpartners_092110.pdf: 30 chunks
# OK  - wwc_spalding_method_091812.pdf: 13 chunks
# OK  - wwc_spalding_method_101612.pdf: 15 chunks
# OK  - wwc_spelling_mastery_100716.pdf: 38 chunks
# OK  - wwc_spellread_102116.pdf: 57 chunks
# OK  - wwc_srsd_111417.pdf: 132 chunks
# OK  - wwc_step_052709.pdf: 38 chunks
# OK  - wwc_str_111511.pdf: 39 chunks
# OK  - wwc_successmaker_111715.pdf: 58 chunks
# OK  - wwc_summer_counseling_032718.pdf: 82 chunks
# OK  - wwc_summerbridge_031715.pdf: 56 chunks
# OK  - wwc_summerbridge_071916.pdf: 64 chunks
# OK  - wwc_tap_012517.pdf: 64 chunks
# OK  - wwc_tdmg_011513.pdf: 42 chunks
# OK  - wwc_tdmg_030309.pdf: 9 chunks
# OK  - wwc_teemss_050812.pdf: 26 chunks
# OK  - wwc_teenoutreach_010609.pdf: 5 chunks
# OK  - wwc_tfa_083116.pdf: 150 chunks
# OK  - wwc_thinkertools_021412.pdf: 8 chunks
# OK  - wwc_tntp_062717.pdf: 65 chunks
# OK  - wwc_tools_010813.pdf: 8 chunks
# OK  - wwc_toolsofmind_091608.pdf: 57 chunks
# OK  - wwc_ucsmp_052416.pdf: 75 chunks
# OK  - wwc_vmath_030513.pdf: 8 chunks
# OK  - wwc_voyages_030513.pdf: 8 chunks
# OK  - wwc_vrp_031610.pdf: 20 chunks
# OK  - wwc_wilson_070110.pdf: 12 chunks
# OK  - wwc_words_022013.pdf: 17 chunks
# OK  - wwc_youth_corps_092910.pdf: 17 chunks
# OK  - wwc_youthbuild_110309.pdf: 10 chunks

# %%
# ----------------------------
# 5) Save JSON outputs
# ----------------------------
OUTPUT_JSON.parent.mkdir(parents=True, exist_ok=True)

with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump(output, f, ensure_ascii=False, indent=2)

with open(ERRORS_JSON, "w", encoding="utf-8") as f:
    json.dump(errors, f, ensure_ascii=False, indent=2)

print("\nSaved:")
print(" -", OUTPUT_JSON)
print(" -", ERRORS_JSON)
print(f"Total chunks: {len(output)}")
print(f"Total errors: {len(errors)}")
# Out:
# Saved:
#  - /content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports/intervention_reports_chunks.json
#  - /content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports/intervention_reports_errors.json
# Total chunks: 11724
# Total errors: 1

# %%
import json
import re
from pathlib import Path

chunks_path = Path("/content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports/intervention_reports_chunks.json")
meta_path = Path("/content/drive/MyDrive/OpenEduDemo/1a-intervention_reports/intervention_reports/intervention_reports_meta.json")

with open(chunks_path, "r", encoding="utf-8") as f:
    chunks = json.load(f)

meta = {}

for key in chunks.keys():
    # eg：plato_030210__chunk0007
    parts = key.split("__")

    report_id = parts[0]

    chunk_index = None
    for p in parts:
        if p.startswith("chunk"):
            chunk_index = int(p.replace("chunk", ""))

    meta[key] = {
        "report_id": report_id,
        "chunk_index": chunk_index,
        "source_type": "WWC Intervention Report"
    }

with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, ensure_ascii=False, indent=2)

print(f"Saved metadata for {len(meta)} chunks")
# Out:
# Saved metadata for 11724 chunks
